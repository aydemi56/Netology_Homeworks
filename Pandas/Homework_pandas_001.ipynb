# %% [markdown]
# ## Оглавление
# 1. [Задача 1](#task1)
# 2. [Задача 2](#task2)
# 3. [Задача 3](#task3)

# %% [markdown]
# ## Задача 1
# <a id='task1'></a>
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %% [markdown]
# ### В этом задании есть файлы, с которыми я работаю
# ### Нужно ли эти файлы как-то тоже загружать на github репозиторий, чтобы код правильно работал у Вас?

# %%
ds = pd.read_csv(r'C:\Users\aydem\Desktop\Netology_Homeworks\Netology_Homeworks\Pandas\ml-latest-small\ratings.csv')
ds[ds['rating']==5.0]['movieId'].value_counts().head(1)
# Out:
# 318    153
# Name: movieId, dtype: int64

# %%
ds_names = pd.read_csv(r'C:\Users\aydem\Desktop\Netology_Homeworks\Netology_Homeworks\Pandas\ml-latest-small\movies.csv')
ds_names[ds_names['movieId']==318]['title']
# Out:
# 277    Shawshank Redemption, The (1994)
# Name: title, dtype: object

# %% [markdown]
# ## Задача 2
# <a id='task2'></a>
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
o['country'].unique()

# %%
power = pd.read_csv(r'C:\Users\aydem\Desktop\Netology_Homeworks\Netology_Homeworks\Pandas\power.csv')
power.head(10)
filtered_countries = power[ (power['country']=='Litva') | (power['country']=='Latvia') | (power['country']=='Estonia')]
filtered_category = filtered_countries[ (filtered_countries['category']==4) | (filtered_countries['category']==12) | (filtered_countries['category']==21)]
filtered_period = filtered_category[(filtered_category['year']>=2005)&(filtered_category['year']<=2010)]
filtered_period['quantity'].sum()
# Out:
# 118284.0

# %% [markdown]
# ## Задача 3
# <a id='task3'></a>
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# www.finanz.ru...om-vremeni

# %%
pd.read_html('https://fortrader.org/quotes', encoding='utf-8')[0]
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  86.21       -0.0          -0.0        NaN
# 1       USDRUB Курс рубля к доллару  73.15        0.0           0.0        NaN

# %%
pd.read_html('https://fortrader.org/quotes', encoding='utf-8')[1]
# Out:
#                               Название    Цена  Изменение  Изменение(%)  \
# 0       Нефть Brent Курс нефти сегодня   76.09       0.01          0.01
# 1          Нефть WTI Цены на нефть WTI   75.10       0.04          0.05
# 2  Природный газ Цена на природный газ    3.69      -0.01         -0.16
# 3                                 Кофе  153.05       0.00          0.00
# 4                             Кукуруза  591.40      -0.60         -0.10
# 5                                  Соя  378.00      -2.40         -0.63
# 6                               Хлопок   86.97       0.00          0.00
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN

# %%
pd.read_html('https://fortrader.org/quotes', encoding='utf-8')[2]
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0       Золото Цена золота на бирже  1 787       -0.0          -0.0        NaN
# 1  Серебро Цена на серебро на бирже  26.45        0.0           0.0        NaN
# 2         Палладий Цена на Палладий  2 785       -4.0          -0.0        NaN
# 3           Платина Цены на платину  1 090       -1.0          -0.0        NaN
# 4           Медь Цена меди на бирже   4.28        0.0           0.0        NaN

# %%
pd.read_html('https://fortrader.org/quotes', encoding='utf-8')[4]
# Out:
#                                Название      Цена  Изменение  Изменение(%)  \
# 0           Google Акции Google (GOOGL)  2 504.25      -0.90         -0.04
# 1                   IBM Акции IBM (IBM)    140.20       0.18          0.13
# 2     Microsoft Акции Майкрософт (MSFT)    277.50      -0.15         -0.05
# 3              Apple Акции Apple (AAPL)    139.83      -0.13         -0.09
# 4                  Yandex Акции яндекса     71.09      -0.23         -0.32
# 5                   Toyota Акции Тойоты    174.50      -1.53         -0.87
# 6      Volkswagen Курс акций Volkswagen    211.45       0.15          0.07
# 7            Amazon Акции Amazon (AMZN)  3 510.01      -0.97         -0.03
# 8           Boeing Акции Boeing Company    236.69       0.01          0.00
# 9              Intel Акции Intel (INTC)     56.63      -0.13         -0.23
# 10            Coca-Cola Акции Coca-Cola     54.13      -0.05         -0.09
# ...
